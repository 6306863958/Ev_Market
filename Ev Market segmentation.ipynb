# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv('car data.csv')
df1.head(2)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0

# %%
df1['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64

# %%
# fetching dataset - 2
df2 = pd.read_excel('2_ev_charging_station_dataset.xlsx', sheet_name='Table 4', header=1)
df2.head()
# Out:
#             State/UT  EV Charging Facility
# 0     Andhra Pradesh                    65
# 1  Arunachal Pradesh                     4
# 2              Assam                    19
# 3              Bihar                    26
# 4         Chandigarh                     4

# %%
df3=pd.read_csv('Sagar_ev_dataset1.csv')
df3.head(2)
# Out:
#    Unnamed: 0        Brand                          Model  AccelSec  \
# 0           0       Tesla   Model 3 Long Range Dual Motor       4.6
# 1           1  Volkswagen                       ID.3 Pure      10.0
#
#    TopSpeed_KmH  Range_Km  Efficiency_WhKm  FastCharge_KmH RapidCharge  \
# 0           233       450              161             940         Yes
# 1           160       270              167             250          No
#
#   PowerTrain    PlugType  BodyStyle Segment  Seats  PriceEuro
# 0        AWD  Type 2 CCS      Sedan       D      5      55480
# 1        RWD  Type 2 CCS  Hatchback       C      5      30000

# %%
# model 1 analysis

# %%
petrol_data=df1[df1['Fuel_Type']=='Petrol']
Diesel_data=df1[df1['Fuel_Type']=='Diesel']
CNG_data=df1[df1['Fuel_Type']=='CNG']

# %%
petrol_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 239 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       239 non-null    object
#  1   Year           239 non-null    int64
#  2   Selling_Price  239 non-null    float64
#  3   Present_Price  239 non-null    float64
#  4   Kms_Driven     239 non-null    int64
#  5   Fuel_Type      239 non-null    object
#  6   Seller_Type    239 non-null    object
#  7   Transmission   239 non-null    object
#  8   Owner          239 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 18.7+ KB

# %%
Diesel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 1 to 299
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       60 non-null     object
#  1   Year           60 non-null     int64
#  2   Selling_Price  60 non-null     float64
#  3   Present_Price  60 non-null     float64
#  4   Kms_Driven     60 non-null     int64
#  5   Fuel_Type      60 non-null     object
#  6   Seller_Type    60 non-null     object
#  7   Transmission   60 non-null     object
#  8   Owner          60 non-null     int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 4.7+ KB

# %%
CNG_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 18 to 35
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       2 non-null      object
#  1   Year           2 non-null      int64
#  2   Selling_Price  2 non-null      float64
#  3   Present_Price  2 non-null      float64
#  4   Kms_Driven     2 non-null      int64
#  5   Fuel_Type      2 non-null      object
#  6   Seller_Type    2 non-null      object
#  7   Transmission   2 non-null      object
#  8   Owner          2 non-null      int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 160.0+ bytes

# %%
petrol_data.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
Diesel_data.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
CNG_data.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
petrol_data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   239.000000     239.000000     239.000000     239.000000  239.000000
# mean   2013.539749       3.264184       5.583556   33528.937238    0.050209
# std       3.042674       3.135537       5.290685   40308.984886    0.270368
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.600000       0.940000   13850.000000    0.000000
# 50%    2014.000000       2.650000       4.600000   25870.000000    0.000000
# 75%    2016.000000       5.200000       7.980000   44271.000000    0.000000
# max    2017.000000      19.750000      23.730000  500000.000000    3.000000

# %%
Diesel_data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven      Owner
# count    60.000000      60.000000      60.000000      60.000000  60.000000
# mean   2014.000000      10.278500      15.814500   50369.916667   0.016667
# std       2.201694       7.185159      13.484289   30021.446979   0.129099
# min    2005.000000       3.100000       5.700000    2071.000000   0.000000
# 25%    2013.000000       5.137500       8.912500   38750.000000   0.000000
# 50%    2014.000000       7.750000      10.585000   45000.000000   0.000000
# 75%    2015.000000      12.600000      17.010000   59250.000000   0.000000
# max    2018.000000      35.000000      92.600000  197176.000000   1.000000

# %%
CNG_data.describe()
# Out:
#               Year  Selling_Price  Present_Price    Kms_Driven  Owner
# count     2.000000       2.000000       2.000000      2.000000    2.0
# mean   2013.000000       3.100000       6.415000  42749.000000    0.0
# std       2.828427       0.212132       1.873833  10251.634114    0.0
# min    2011.000000       2.950000       5.090000  35500.000000    0.0
# 25%    2012.000000       3.025000       5.752500  39124.500000    0.0
# 50%    2013.000000       3.100000       6.415000  42749.000000    0.0
# 75%    2014.000000       3.175000       7.077500  46373.500000    0.0
# max    2015.000000       3.250000       7.740000  49998.000000    0.0

# %%
# graph between selling price and present price of Diesel_data year per year

# %%
plt.figure(figsize=(12, 12))

# Scatter plot with different colors for each year
sns.scatterplot(data=Diesel_data, x='Selling_Price', y='Present_Price', hue='Year', palette='viridis', s=100)

# Line plot for trend
sns.regplot(x='Selling_Price', y='Present_Price', data=Diesel_data, scatter=False, color='red', label='Trend Line')

# Labels and title
plt.xlabel('Selling Price')
plt.ylabel('Present Price')
plt.title('Relationship between Selling Price and Present Price by Year')
plt.legend(title='Year')
plt.grid(True)

# Show the plot
plt.show()

# %%
# graph between selling price and present price of petrol_data year per year

# %%
plt.figure(figsize=(12, 12))

# Scatter plot with different colors for each year
sns.scatterplot(data=petrol_data, x='Selling_Price', y='Present_Price', hue='Year', palette='viridis', s=100)

# Line plot for trend
sns.regplot(x='Selling_Price', y='Present_Price', data=petrol_data, scatter=False, color='red', label='Trend Line')

# Labels and title
plt.xlabel('Selling Price')
plt.ylabel('Present Price')
plt.title('Relationship between Selling Price and Present Price by Year')
plt.legend(title='Year')
plt.grid(True)

# Show the plot
plt.show()

# %%
# graph between selling price and present price of CNG data year per year

# %%
plt.figure(figsize=(12, 12))

# Scatter plot with different colors for each year
sns.scatterplot(data=CNG_data, x='Selling_Price', y='Present_Price', hue='Year', palette='viridis', s=100)

# Line plot for trend
sns.regplot(x='Selling_Price', y='Present_Price', data=CNG_data, scatter=False, color='red', label='Trend Line')

# Labels and title
plt.xlabel('Selling Price')
plt.ylabel('Present Price')
plt.title('Relationship between Selling Price and Present Price by Year')
plt.legend(title='Year')
plt.grid(True)

# Show the plot
plt.show()

# %%
plt.plot(petrol_data['Year'], petrol_data['Selling_Price'])
plt.xlabel('Year')
plt.ylabel('Selling Price')
plt.title('Selling Price vs Year')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'petrol_data' is your DataFrame
years = petrol_data['Year'].unique()
colors = plt.cm.viridis(np.linspace(0, 1, len(years)))

for year, color in zip(years, colors):
    year_data = petrol_data[petrol_data['Year'] == year]
    plt.scatter(year_data['Year'], year_data['Selling_Price'], label=year, color=color)

plt.xlabel('Year')
plt.ylabel('Selling Price')
plt.title('Selling Price vs Year')
plt.legend(title='Year')
plt.show()

# %%
# Assuming 'petrol_data' is your DataFrame
years = Diesel_data['Year'].unique()
colors = plt.cm.viridis(np.linspace(0, 1, len(years)))

for year, color in zip(years, colors):
    year_data =Diesel_data[Diesel_data['Year'] == year]
    plt.scatter(year_data['Year'], year_data['Selling_Price'], label=year, color=color)

plt.xlabel('Year')
plt.ylabel('Selling Price')
plt.title('Selling Price vs Year')
plt.legend(title='Year')
plt.show()

# %%
# Assuming 'petrol_data' is your DataFrame
years = CNG_data['Year'].unique()
colors = plt.cm.viridis(np.linspace(0, 1, len(years)))

for year, color in zip(years, colors):
    year_data = CNG_data[CNG_data['Year'] == year]
    plt.scatter(year_data['Year'], year_data['Selling_Price'], label=year, color=color)

plt.xlabel('Year')
plt.ylabel('Selling Price')
plt.title('Selling Price vs Year')
plt.legend(title='Year')
plt.show()

# %% [markdown]
# How the price change in year 2011,2015

# %%
pe_data=petrol_data[petrol_data['Year']==2011]['Selling_Price'].mean()
pe1_data=petrol_data[petrol_data['Year']==2015]['Selling_Price'].mean()

# %%
de_data=Diesel_data[Diesel_data['Year']==2011]['Selling_Price'].mean()
de1_data=Diesel_data[Diesel_data['Year']==2015]['Selling_Price'].mean()

# %%
cn_data=CNG_data[CNG_data['Year']==2011]['Selling_Price'].mean()
cn1_data=CNG_data[CNG_data['Year']==2015]['Selling_Price'].mean()

# %%
data = {
    'Year': [2011,2015],
    'Petrol_Price': [pe_data, pe1_data],
    'Diesel_Price': [de_data, de1_data],
    'CNG_Price': [cn_data, cn1_data]
}

# %%
compare_mean=pd.DataFrame(data)

# %%
compare_mean
# Out:
#    Year  Petrol_Price  Diesel_Price  CNG_Price
# 0  2011      2.216471      4.500000       2.95
# 1  2015      4.253333     11.126667       3.25

# %%
years = compare_mean['Year']
mean_petrol_price  = compare_mean['Petrol_Price']
mean_diesel_price = compare_mean['Diesel_Price']
mean_cng_price = compare_mean['CNG_Price']

bar_width = 0.25
bar_positions = np.arange(len(years))

plt.bar(bar_positions, mean_petrol_price, width=bar_width, label='Petrol', color='b')
plt.bar(bar_positions + bar_width, mean_diesel_price, width=bar_width, label='Diesel', color='g')
plt.bar(bar_positions + 2 * bar_width, mean_cng_price , width=bar_width, label='CNG', color='r')

plt.xlabel('Year')
plt.ylabel('Price')
plt.title('CNG, Petrol, and Diesel Prices per Year')
plt.xticks(bar_positions + bar_width, years)
plt.legend()

plt.show()

# %%
len(petrol_data)
# Out:
# 239

# %%
len(Diesel_data)
# Out:
# 60

# %%
len(CNG_data)
# Out:
# 2

# %%
# since their is less amount of cng data so we can try cng for selling in the market as price of cng is also low as compare to other

# %% [markdown]
# Analysis of charging stations sanctioned

# %%
df2.head()
# Out:
#             State/UT  EV Charging Facility
# 0     Andhra Pradesh                    65
# 1  Arunachal Pradesh                     4
# 2              Assam                    19
# 3              Bihar                    26
# 4         Chandigarh                     4

# %%
# Set the figure size
plt.figure(figsize=(10, 8))

# Create a horizontal bar plot
sns.barplot(data=df2, x='EV Charging Facility', y='State/UT', palette='coolwarm', orient='h')

# Set the labels and title
plt.xlabel('Number of Retail Outlets for Charging EVs', fontsize=12, family='serif', labelpad=10)
plt.ylabel('State/UT', fontsize=12, family='serif')
plt.xticks(family='serif', size=10)
plt.yticks(family='serif', size=10)
plt.title('Available Retail Outlets for Charging EVs in India', fontsize=15, family='serif', pad=12)

# Show the plot
plt.show()

# %% [markdown]
# Analysis on 3rd dataset

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   AccelSec         103 non-null    float64
#  1   TopSpeed_KmH     103 non-null    int64
#  2   Range_Km         103 non-null    int64
#  3   Efficiency_WhKm  103 non-null    int64
#  4   FastCharge_KmH   103 non-null    int64
#  5   Seats            103 non-null    int64
#  6   PriceEuro        103 non-null    int64
# dtypes: float64(1), int64(6)
# memory usage: 5.8 KB

# %%
df3.isna().sum()
# Out:
# AccelSec           0
# TopSpeed_KmH       0
# Range_Km           0
# Efficiency_WhKm    0
# FastCharge_KmH     0
# Seats              0
# PriceEuro          0
# dtype: int64

# %%
df3.duplicated().sum()
# Out:
# 0

# %%
df3.nunique()
# Out:
# AccelSec           55
# TopSpeed_KmH       25
# Range_Km           50
# Efficiency_WhKm    54
# FastCharge_KmH     51
# Seats               5
# PriceEuro          87
# dtype: int64

# %% [markdown]
# Anaysis of different body types of EVs
# Observation: SUV and Hatchback body types form the majority while Station and MPV the minority.

# %%
# different body types EVs visualization from dataset 3
x = df3['BodyStyle'].value_counts().plot.pie(radius=2, cmap='viridis', startangle=0, textprops=dict(family='serif'))
plt.pie(x=[1], radius=1.2, colors='white')
plt.title(label='Electric Vehicles of Different Body Types in India', family='serif', size=15, pad=100)
plt.ylabel('')
plt.show()

# %% [markdown]
# Analysis of different segments of EVs
# Observation: B and C body segments form the majority while S and A the minority.

# %%
# analysis of different segments of EVs from dataset 3
x = df3['Segment'].value_counts().plot.pie(radius=2, cmap='viridis', startangle=0, textprops=dict(family='serif'), pctdistance=.5)
plt.pie(x=[1], radius=1.2, colors='white')
plt.title(label='Electric Vehicles of Different Segments in India', family='serif', size=15, pad=100)
plt.ylabel('')
plt.show()

# %%
# EVs of different number of seats from dataset 3
sns.countplot(data=df3, x='Seats')
plt.xlabel('Number of Seats')
plt.ylabel('Count')
plt.title(label='Available Electric Vehicles of Different Number of Seats in India', family='serif', size=15, pad=12)
plt.show()

# %% [markdown]
# Analysis of different plug types
# Observation: EVs with plus type of 'Type 2 CCS' seem to dominate the market'.

# %%
df3['PlugType'].value_counts().sort_values(ascending=True).plot.barh()
plt.xlabel('Count', family='serif', size=12)
plt.ylabel('Plug Type', family='serif', size=12)
plt.xticks(family='serif')
plt.yticks(family='serif')
plt.title('Available Plug Types of EVs in India', family='serif', size=15)
plt.show()

# %%
#Analysis of EVs based on accleration
#Observation: Based on accleration, EVs from Renault, Seat and Smart are the top performers while Tesla, Lucid and Porsche dont make it to the same.


# accleration visualization from dataset 3
plt.figure(figsize=(6, 8))
sns.barplot(data=df3, y='Brand', x='AccelSec', ci=None, palette='viridis')
plt.xticks(family='serif')
plt.yticks(family='serif')
plt.xlabel('Accleration', family='serif', size=12)
plt.ylabel('Brand', family='serif', size=12)
plt.title(label='Accleration of EVs in India', family='serif', size=15, pad=12)
plt.show()
# Out:
# C:\Users\Sagar\AppData\Local\Temp\ipykernel_3136\1686340869.py:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df3, y='Brand', x='AccelSec', ci=None, palette='viridis')

# %%
df31=df3.drop(['Unnamed: 0','Brand','Model','PowerTrain','PlugType','BodyStyle','RapidCharge','Segment'],axis=1)

# %%
# plotting the correlation matrix from dataset 3
plt.figure(figsize=(6,6))
sns.heatmap(data=df31.corr(), annot=True, cmap='Purples', cbar=False, square=True, fmt='.2f', linewidths=.3)
plt.title('Correlation Matrix', family='serif', size=15, pad=12);

# %%
# this simple data taken from goggle 
import matplotlib.pyplot as plt

# Sample data for the bar chart (EV Sales Growth from 2019 to 2023)
years = [2019, 2020, 2021, 2022, 2023]
electric_cars_sales = [1.2, 1.5, 2.0, 2.5, 3.0]  # in millions
electric_bikes_sales = [0.8, 1.0, 1.4, 1.8, 2.2]  # in millions
electric_trucks_sales = [0.3, 0.4, 0.6, 0.9, 1.2]  # in millions
electric_buses_sales = [0.2, 0.3, 0.4, 0.6, 0.8]  # in millions

# Sample data for the pie chart (Market Share by EV Type in 2023)
labels = 'Electric Cars', 'Electric Bikes/Scooters', 'Electric Trucks/Vans', 'Electric Buses'
market_share = [50, 30, 15, 5]  # in percentages

# Create the bar chart
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.bar(years, electric_cars_sales, width=0.2, label='Electric Cars', align='center')
plt.bar([year + 0.2 for year in years], electric_bikes_sales, width=0.2, label='Electric Bikes/Scooters', align='center')
plt.bar([year + 0.4 for year in years], electric_trucks_sales, width=0.2, label='Electric Trucks/Vans', align='center')
plt.bar([year + 0.6 for year in years], electric_buses_sales, width=0.2, label='Electric Buses', align='center')
plt.xlabel('Year')
plt.ylabel('Sales (in millions)')
plt.title('EV Sales Growth (2019-2023)')
plt.legend()

# Create the pie chart
plt.subplot(1, 2, 2)
plt.pie(market_share, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Market Share by EV Type (2023)')

plt.tight_layout()
plt.show()

# %%
# from this data we can say electri cars can make more profit

# %% [markdown]
# Model Building

# %%
# encoding the categorical features

# PowerTrain feature
df3['PowerTrain'].replace(to_replace=['RWD','FWD','AWD'],value=[0, 1, 2],inplace=True)

# RapidCharge feature
df3['RapidCharge'].replace(to_replace=['No','Yes'],value=[0, 1],inplace=True)
# Out:
# C:\Users\Sagar\AppData\Local\Temp\ipykernel_3136\3916867689.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df3['PowerTrain'].replace(to_replace=['RWD','FWD','AWD'],value=[0, 1, 2],inplace=True)
# ...

# %%
# selecting features for building a model
X = df3[['AccelSec','TopSpeed_KmH','Efficiency_WhKm','FastCharge_KmH', 'Range_Km', 'RapidCharge', 'Seats', 'PriceEuro','PowerTrain']]
     

# feature scaling
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
     
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
# applying Principle Component Analysis (PCA)
pca = PCA(n_components=9)
X_pca = pca.fit_transform(X_scaled)
df_pca = pd.DataFrame(X_pca, columns=['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9'])
df_pca.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0  2.429225 -0.554599 -1.147772 -0.882791  0.839988 -0.959297  0.998880
# 1 -2.322483 -0.345449  0.896473 -1.305529  0.079598  0.235116 -0.213678
# 2  1.587851  0.008899 -0.650523  0.041024  0.593537 -0.698248  0.058718
# 3  0.291018 -0.000150 -0.307702 -0.514196 -1.608861  0.291624  0.364999
# 4 -2.602679 -0.626489 -0.888088  0.585294 -0.802108  0.027387 -0.084955
#
#         PC8       PC9
# 0  0.711148 -0.396662
# 1 -0.544135 -0.181867
# 2  0.248837 -0.202775
# 3 -0.235543  0.261663
# 4 -0.507790 -0.049904

# %%
wcss = []
for i in range(1, 11):
    kmean = KMeans(n_clusters=i, init='k-means++', random_state=90)
    kmean.fit(X_pca)
    wcss.append(kmean.inertia_)

# Plot the results
plt.figure(figsize=(8, 6))
plt.title('Plot of the Elbow Method', size=15, family='serif')

# Plotting with markers and different line style
plt.plot(range(1, 11), wcss, marker='o', linestyle='--', color='b')

plt.xticks(range(1, 11), family='serif')
plt.yticks(family='serif')
plt.xlabel('Number of Clusters (K)', family='serif')
plt.ylabel('WCSS', family='serif')
plt.grid()
plt.tick_params(axis='both', direction='inout', length=6, color='purple', grid_color='lightgray', grid_linestyle='--')
plt.show()
# Out:
# C:\Users\Sagar\anaconda3\file\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Sagar\anaconda3\file\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Sagar\anaconda3\file\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
# training the model using k=4 as rendered by the above plot
kmean = KMeans(n_clusters=4, init='k-means++', random_state=90)
kmean.fit(X_pca)
# Out:
# C:\Users\Sagar\anaconda3\file\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=4, random_state=90)

# %%
# check the labels assigned to each data point
print(kmean.labels_)
# Out:
# [1 3 1 0 3 1 3 2 0 1 1 2 2 0 3 0 1 3 3 2 2 1 2 1 1 0 0 1 3 3 1 2 2 1 2 2 2
#  0 3 2 1 2 1 3 3 2 2 1 2 2 1 1 2 0 1 3 2 3 2 1 3 1 0 1 0 1 2 1 3 1 2 2 1 1
#  2 2 1 3 1 1 0 1 3 0 0 2 0 1 1 0 1 3 2 1 2 0 2 0 2 1 1 1 1]

# %%
# check the size of clusters
pd.Series(kmean.labels_).value_counts()
# Out:
# 1    38
# 2    30
# 3    18
# 0    17
# Name: count, dtype: int64

# %%
# adding a new feature of cluster labels to the dataset 3
df3['clusters'] = kmean.labels_

# %%
# visualizing clusters
plt.figure(figsize=(7,5))
sns.scatterplot(data=df_pca, x='PC1', y='PC2', s=70, hue=kmean.labels_, palette='viridis', zorder=2, alpha=.9)
plt.scatter(x=kmean.cluster_centers_[:,0], y=kmean.cluster_centers_[:,1], marker="*", c="r", s=80, label="centroids")
plt.xlabel('PC1', family='serif', size=12)
plt.ylabel('PC9', family='serif', size=12)
plt.xticks(family='serif')
plt.yticks(family='serif')
plt.grid()
plt.tick_params(grid_color='lightgray', grid_linestyle='--', zorder=1)
plt.legend(title='Labels', fancybox=True, shadow=True)
plt.title('K-Means Clustering Results', family='serif', size=15)
plt.show()
